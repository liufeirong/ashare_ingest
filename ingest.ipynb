# %%
import numpy as np
import pandas as pd

import time
import datetime
import threading
import redis

import tushare as ts
from concurrent import futures
from utils.time_util import time_cut

red = redis.Redis(host='localhost')

# %%
stock_basics = ts.get_stock_basics()
tickers = stock_basics[(stock_basics['name'].str.find('ST')==-1) & (stock_basics['timeToMarket']>19900101) & (stock_basics['timeToMarket']<20190101)
            & (stock_basics['npr']>0)].index.values.tolist()

# %%
MAX_WORKERS = 30
executor = futures.ThreadPoolExecutor(max_workers=MAX_WORKERS)
def get_realtime_quotes(tickers, workers=MAX_WORKERS):
    N = (len(tickers)+workers-1)//workers
    tickers_list = [tickers[i*N:min(i*N+N, len(tickers))] for i in range((len(tickers)+N-1)//N)]
    results = executor.map(ts.get_realtime_quotes, tickers_list)
    df = pd.concat(results)
    df['time'] = df['time'].apply(time_cut)
    return df.reset_index()

# %%
def run_get_realtime_quotes(tickers):
    cur_datetime = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
    cur_date = cur_datetime[0:10]
    am_start_time = cur_date + ' 09:25:00'
    am_end_time = cur_date + ' 11:30:00'
    pm_start_time = cur_date + ' 13:00:00'
    pm_end_time = cur_date + ' 15:00:00'
    ingest_time = am_start_time
    if cur_datetime < am_start_time:
        print('no open market!')
        return
    if len(red.keys('t_tick_'+pm_end_time)) > 0 and cur_datetime > pm_end_time:
        print('ingest over all tick!')
        return
    df_buffer = None
    while ingest_time < pm_end_time:
        cur_datetime = datetime.datetime.now()
        try:
            df = get_realtime_quotes(tickers)
        except Exception as e:
            if cur_datetime>pd.to_datetime(pm_end_time):
                break
            print('time out!')
            continue
        date_tick = df.iloc[0]['date']
        time_tick = df.iloc[0]['time']
        if date_tick is None:
            date_tick = cur_date
        if time_tick is None:
            time_tick = cur_datetime.strftime('%H:%M:%S')
        time_tick = time_cut(time_tick)
        date_time = date_tick + ' ' + time_tick
        df['datetime'] = pd.to_datetime(date_time)
        df = df[['code', 'datetime', 'price', 'volume', 'amount']].dropna()
        if df_buffer is None:
            df_buffer = df
        elif date_time[:-3] == ingest_time[:-3] or date_time[-2:] == '00':
            df_buffer = pd.concat([df_buffer, df])
        if date_time[:-3] > ingest_time[:-3]:
            key = 't_tick_' + date_time[:-3] +':00'
            df_tick_bytes = df_buffer.to_msgpack()
            red.set(key, df_tick_bytes)
            df_buffer = df
            if date_time[-2:] == '00':
                df_buffer = None
            print(ingest_time + '  has ingest into table ' + key + '!')
            ingest_time = date_time
        if ingest_time >= am_end_time and ingest_time < pm_start_time:
            print('Noon break time!')
            time.sleep((pd.to_datetime(pm_start_time)-datetime.datetime.now()).total_seconds())
            continue

# %%
run_get_realtime_quotes(tickers)
# Out:
# /Users/harry/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:41: FutureWarning: to_msgpack is deprecated and will be removed in a future version.
# It is recommended to use pyarrow for on-the-wire transmission of pandas objects.
# 2020-03-03 09:25:00  has ingest into table t_tick_2020-03-03 11:30:00!
# Noon break time!
# Noon break time!
# 2020-03-03 11:30:00  has ingest into table t_tick_2020-03-03 13:00:00!
# 2020-03-03 13:00:00  has ingest into table t_tick_2020-03-03 13:01:00!
# 2020-03-03 13:01:00  has ingest into table t_tick_2020-03-03 13:02:00!
# 2020-03-03 13:02:03  has ingest into table t_tick_2020-03-03 13:03:00!
# 2020-03-03 13:03:00  has ingest into table t_tick_2020-03-03 13:04:00!
# 2020-03-03 13:04:00  has ingest into table t_tick_2020-03-03 13:05:00!
# 2020-03-03 13:05:00  has ingest into table t_tick_2020-03-03 13:06:00!
# 2020-03-03 13:06:03  has ingest into table t_tick_2020-03-03 13:07:00!
# 2020-03-03 13:07:00  has ingest into table t_tick_2020-03-03 13:08:00!
# 2020-03-03 13:08:00  has ingest into table t_tick_2020-03-03 13:09:00!
# 2020-03-03 13:09:00  has ingest into table t_tick_2020-03-03 13:10:00!
# 2020-03-03 13:10:00  has ingest into table t_tick_2020-03-03 13:11:00!
# 2020-03-03 13:11:03  has ingest into table t_tick_2020-03-03 13:12:00!
# 2020-03-03 13:12:00  has ingest into table t_tick_2020-03-03 13:13:00!
# 2020-03-03 13:13:00  has ingest into table t_tick_2020-03-03 13:14:00!
# 2020-03-03 13:14:00  has ingest into table t_tick_2020-03-03 13:15:00!
# 2020-03-03 13:15:00  has ingest into table t_tick_2020-03-03 13:16:00!
# 2020-03-03 13:16:00  has ingest into table t_tick_2020-03-03 13:17:00!
# 2020-03-03 13:17:00  has ingest into table t_tick_2020-03-03 13:18:00!
# 2020-03-03 13:18:00  has ingest into table t_tick_2020-03-03 13:19:00!
# 2020-03-03 13:19:00  has ingest into table t_tick_2020-03-03 13:20:00!
# 2020-03-03 13:20:00  has ingest into table t_tick_2020-03-03 13:21:00!
# 2020-03-03 13:21:00  has ingest into table t_tick_2020-03-03 13:22:00!
# 2020-03-03 13:22:00  has ingest into table t_tick_2020-03-03 13:23:00!
# 2020-03-03 13:23:00  has ingest into table t_tick_2020-03-03 13:24:00!
# 2020-03-03 13:24:00  has ingest into table t_tick_2020-03-03 13:25:00!
# 2020-03-03 13:25:03  has ingest into table t_tick_2020-03-03 13:26:00!
# 2020-03-03 13:26:00  has ingest into table t_tick_2020-03-03 13:27:00!
# 2020-03-03 13:27:00  has ingest into table t_tick_2020-03-03 13:28:00!
# 2020-03-03 13:28:00  has ingest into table t_tick_2020-03-03 13:29:00!
# 2020-03-03 13:29:03  has ingest into table t_tick_2020-03-03 13:30:00!
# 2020-03-03 13:30:00  has ingest into table t_tick_2020-03-03 13:31:00!
# 2020-03-03 13:31:06  has ingest into table t_tick_2020-03-03 13:32:00!
# 2020-03-03 13:32:00  has ingest into table t_tick_2020-03-03 13:33:00!
# 2020-03-03 13:33:06  has ingest into table t_tick_2020-03-03 13:34:00!
# 2020-03-03 13:34:00  has ingest into table t_tick_2020-03-03 13:35:00!
# 2020-03-03 13:35:00  has ingest into table t_tick_2020-03-03 13:36:00!
# 2020-03-03 13:36:06  has ingest into table t_tick_2020-03-03 13:37:00!
# 2020-03-03 13:37:00  has ingest into table t_tick_2020-03-03 13:38:00!
# 2020-03-03 13:38:00  has ingest into table t_tick_2020-03-03 13:39:00!
# 2020-03-03 13:39:03  has ingest into table t_tick_2020-03-03 13:40:00!
# 2020-03-03 13:40:00  has ingest into table t_tick_2020-03-03 13:41:00!
# 2020-03-03 13:41:03  has ingest into table t_tick_2020-03-03 13:42:00!
# 2020-03-03 13:42:00  has ingest into table t_tick_2020-03-03 13:43:00!
# 2020-03-03 13:43:03  has ingest into table t_tick_2020-03-03 13:44:00!
# 2020-03-03 13:44:00  has ingest into table t_tick_2020-03-03 13:45:00!
# 2020-03-03 13:45:00  has ingest into table t_tick_2020-03-03 13:46:00!
# 2020-03-03 13:46:06  has ingest into table t_tick_2020-03-03 13:47:00!
# 2020-03-03 13:47:09  has ingest into table t_tick_2020-03-03 13:48:00!
# 2020-03-03 13:48:00  has ingest into table t_tick_2020-03-03 13:49:00!
# 2020-03-03 13:49:06  has ingest into table t_tick_2020-03-03 13:50:00!
# 2020-03-03 13:50:00  has ingest into table t_tick_2020-03-03 13:51:00!
# 2020-03-03 13:51:00  has ingest into table t_tick_2020-03-03 13:52:00!
# 2020-03-03 13:52:06  has ingest into table t_tick_2020-03-03 13:53:00!
# 2020-03-03 13:53:03  has ingest into table t_tick_2020-03-03 13:54:00!
# time out!
# 2020-03-03 13:54:00  has ingest into table t_tick_2020-03-03 13:55:00!
# 2020-03-03 13:55:00  has ingest into table t_tick_2020-03-03 13:56:00!
# time out!
# 2020-03-03 13:56:03  has ingest into table t_tick_2020-03-03 13:57:00!
# 2020-03-03 13:57:15  has ingest into table t_tick_2020-03-03 13:58:00!
# 2020-03-03 13:58:00  has ingest into table t_tick_2020-03-03 13:59:00!
# 2020-03-03 13:59:03  has ingest into table t_tick_2020-03-03 14:00:00!
# 2020-03-03 14:00:00  has ingest into table t_tick_2020-03-03 14:01:00!
# 2020-03-03 14:01:03  has ingest into table t_tick_2020-03-03 14:02:00!
# 2020-03-03 14:02:00  has ingest into table t_tick_2020-03-03 14:03:00!
# 2020-03-03 14:03:00  has ingest into table t_tick_2020-03-03 14:04:00!
# 2020-03-03 14:04:00  has ingest into table t_tick_2020-03-03 14:05:00!
# time out!
# 2020-03-03 14:05:00  has ingest into table t_tick_2020-03-03 14:06:00!
# 2020-03-03 14:06:12  has ingest into table t_tick_2020-03-03 14:07:00!
# 2020-03-03 14:07:03  has ingest into table t_tick_2020-03-03 14:08:00!
# 2020-03-03 14:08:03  has ingest into table t_tick_2020-03-03 14:09:00!
# 2020-03-03 14:09:00  has ingest into table t_tick_2020-03-03 14:10:00!
# 2020-03-03 14:10:00  has ingest into table t_tick_2020-03-03 14:11:00!
# 2020-03-03 14:11:00  has ingest into table t_tick_2020-03-03 14:12:00!
# 2020-03-03 14:12:03  has ingest into table t_tick_2020-03-03 14:13:00!
# 2020-03-03 14:13:00  has ingest into table t_tick_2020-03-03 14:14:00!
# 2020-03-03 14:14:00  has ingest into table t_tick_2020-03-03 14:15:00!
# 2020-03-03 14:15:00  has ingest into table t_tick_2020-03-03 14:16:00!
# 2020-03-03 14:16:00  has ingest into table t_tick_2020-03-03 14:17:00!
# 2020-03-03 14:17:00  has ingest into table t_tick_2020-03-03 14:18:00!
# 2020-03-03 14:18:00  has ingest into table t_tick_2020-03-03 14:19:00!
# 2020-03-03 14:19:00  has ingest into table t_tick_2020-03-03 14:20:00!
# 2020-03-03 14:20:00  has ingest into table t_tick_2020-03-03 14:21:00!
# 2020-03-03 14:21:03  has ingest into table t_tick_2020-03-03 14:22:00!
# 2020-03-03 14:22:03  has ingest into table t_tick_2020-03-03 14:23:00!
# 2020-03-03 14:23:00  has ingest into table t_tick_2020-03-03 14:24:00!
# 2020-03-03 14:24:00  has ingest into table t_tick_2020-03-03 14:25:00!
# 2020-03-03 14:25:00  has ingest into table t_tick_2020-03-03 14:26:00!
# 2020-03-03 14:26:00  has ingest into table t_tick_2020-03-03 14:27:00!
# 2020-03-03 14:27:06  has ingest into table t_tick_2020-03-03 14:28:00!
# 2020-03-03 14:28:12  has ingest into table t_tick_2020-03-03 14:29:00!
# 2020-03-03 14:29:00  has ingest into table t_tick_2020-03-03 14:30:00!
# 2020-03-03 14:30:06  has ingest into table t_tick_2020-03-03 14:31:00!
# time out!
# 2020-03-03 14:31:06  has ingest into table t_tick_2020-03-03 14:32:00!
# 2020-03-03 14:32:00  has ingest into table t_tick_2020-03-03 14:33:00!
# 2020-03-03 14:33:03  has ingest into table t_tick_2020-03-03 14:34:00!
# 2020-03-03 14:34:06  has ingest into table t_tick_2020-03-03 14:35:00!
# 2020-03-03 14:35:03  has ingest into table t_tick_2020-03-03 14:36:00!
# 2020-03-03 14:36:00  has ingest into table t_tick_2020-03-03 14:37:00!
# 2020-03-03 14:37:03  has ingest into table t_tick_2020-03-03 14:38:00!
# 2020-03-03 14:38:00  has ingest into table t_tick_2020-03-03 14:39:00!
# 2020-03-03 14:39:00  has ingest into table t_tick_2020-03-03 14:40:00!
# 2020-03-03 14:40:06  has ingest into table t_tick_2020-03-03 14:41:00!
# 2020-03-03 14:41:03  has ingest into table t_tick_2020-03-03 14:42:00!
# 2020-03-03 14:42:03  has ingest into table t_tick_2020-03-03 14:43:00!
# 2020-03-03 14:43:00  has ingest into table t_tick_2020-03-03 14:44:00!
# 2020-03-03 14:44:00  has ingest into table t_tick_2020-03-03 14:45:00!
# 2020-03-03 14:45:00  has ingest into table t_tick_2020-03-03 14:46:00!
# 2020-03-03 14:46:03  has ingest into table t_tick_2020-03-03 14:47:00!
# 2020-03-03 14:47:00  has ingest into table t_tick_2020-03-03 14:48:00!
# 2020-03-03 14:48:00  has ingest into table t_tick_2020-03-03 14:49:00!
# 2020-03-03 14:49:00  has ingest into table t_tick_2020-03-03 14:50:00!
# 2020-03-03 14:50:00  has ingest into table t_tick_2020-03-03 14:51:00!
# 2020-03-03 14:51:00  has ingest into table t_tick_2020-03-03 14:52:00!
# 2020-03-03 14:52:00  has ingest into table t_tick_2020-03-03 14:53:00!
# 2020-03-03 14:53:00  has ingest into table t_tick_2020-03-03 14:54:00!
# 2020-03-03 14:54:00  has ingest into table t_tick_2020-03-03 14:55:00!
# 2020-03-03 14:55:00  has ingest into table t_tick_2020-03-03 14:56:00!
# 2020-03-03 14:56:00  has ingest into table t_tick_2020-03-03 14:57:00!
# 2020-03-03 14:57:06  has ingest into table t_tick_2020-03-03 14:58:00!
# 2020-03-03 14:58:00  has ingest into table t_tick_2020-03-03 14:59:00!
# 2020-03-03 14:59:00  has ingest into table t_tick_2020-03-03 15:00:00!
